# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date{end_date}" + 
    f"&fq={filter_query}&sort={sort}&fl={field_list}")

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):
    # create query with a page number
    # API results show 10 articles at a time
    page_query_url = f"{query_url}&page={page}"
    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(page_query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Checked page {page}")

        # Print the page number that had no results then break from the loop
    except:
        print(f"No results found for page {page}")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2024/08/08/movies/it-ends-with-us-review.html",
#         "snippet": "Blake Lively plays Lily Bloom, a flower lover with a thorny personal garden, in this gauzy adaptation of Colleen Hoover\u2019s best-selling novel.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018It Ends With Us\u2019 Review: Love Hurts, and Sometimes Bruises",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Beautiful People Suffer But Avert Messy Reality",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "It Ends With Us (Movie)",
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_list_df = pd.json_normalize(reviews_list)
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2024/08/08/movies/it-e...
# 1    https://www.nytimes.com/2024/07/12/movies/mart...
# 2    https://www.nytimes.com/2024/07/11/movies/fly-...
# 3    https://www.nytimes.com/2024/05/30/movies/hand...
# 4    https://www.nytimes.com/2024/04/25/movies/chal...
# ..                                                 ...
# 195  https://www.nytimes.com/2018/01/18/movies/kang...
# 196  https://www.nytimes.com/2018/01/11/movies/love...
# 197  https://www.nytimes.com/2017/12/14/movies/yout...
# 198  https://www.nytimes.com/2017/12/14/movies/kill...
# 199  https://www.nytimes.com/2017/11/30/movies/the-...
#
#                                                snippet              source  \
# 0    Blake Lively plays Lily Bloom, a flower lover ...  The New York Times
# 1    “Made in England” is an essay film about the a...  The New York Times
# 2    Greg Berlanti’s movie, starring Scarlett Johan...  The New York Times
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_list_df["title"] = reviews_list_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2024/08/08/movies/it-e...
# 1    https://www.nytimes.com/2024/07/12/movies/mart...
# 2    https://www.nytimes.com/2024/07/11/movies/fly-...
# 3    https://www.nytimes.com/2024/05/30/movies/hand...
# 4    https://www.nytimes.com/2024/04/25/movies/chal...
# ..                                                 ...
# 195  https://www.nytimes.com/2018/01/18/movies/kang...
# 196  https://www.nytimes.com/2018/01/11/movies/love...
# 197  https://www.nytimes.com/2017/12/14/movies/yout...
# 198  https://www.nytimes.com/2017/12/14/movies/kill...
# 199  https://www.nytimes.com/2017/11/30/movies/the-...
#
#                                                snippet              source  \
# 0    Blake Lively plays Lily Bloom, a flower lover ...  The New York Times
# 1    “Made in England” is an essay film about the a...  The New York Times
# 2    Greg Berlanti’s movie, starring Scarlett Johan...  The New York Times
# ...

# %%
print(reviews_list_df['keywords'])
# Out:
# 0      [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1      [{'name': 'subject', 'value': 'Documentary Fil...
# 2      [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3      [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4      [{'name': 'subject', 'value': 'Movies', 'rank'...
#                              ...
# 195    [{'name': 'creative_works', 'value': 'Kangaroo...
# 196    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198    [{'name': 'creative_works', 'value': 'Killing ...
# 199    [{'name': 'subject', 'value': 'Movies', 'rank'...
# Name: keywords, Length: 200, dtype: object

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_list_df['keywords'] = reviews_list_df['keywords'].apply(extract_keywords)
reviews_list_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2024/08/08/movies/it-e...
# 1    https://www.nytimes.com/2024/07/12/movies/mart...
# 2    https://www.nytimes.com/2024/07/11/movies/fly-...
# 3    https://www.nytimes.com/2024/05/30/movies/hand...
# 4    https://www.nytimes.com/2024/04/25/movies/chal...
# ..                                                 ...
# 195  https://www.nytimes.com/2018/01/18/movies/kang...
# 196  https://www.nytimes.com/2018/01/11/movies/love...
# 197  https://www.nytimes.com/2017/12/14/movies/yout...
# 198  https://www.nytimes.com/2017/12/14/movies/kill...
# 199  https://www.nytimes.com/2017/11/30/movies/the-...
#
#                                                snippet              source  \
# 0    Blake Lively plays Lily Bloom, a flower lover ...  The New York Times
# 1    “Made in England” is an essay film about the a...  The New York Times
# 2    Greg Berlanti’s movie, starring Scarlett Johan...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_list_df['title'].to_list()
titles
# Out:
# ['It Ends With Us',
#  'From Scorsese With Love: A Tribute to Powell-Pressburger Movie',
#  'Fly Me to the Moon',
#  'Handling the Undead',
#  'Challengers',
#  'Unsung Hero',
#  'Love Lies Bleeding',
#  'Bleeding Love',
#  'Bob Marley: One Love',
#  'Molli and Max in the Future',
#  'The Taste of Things',
#  'Pictures of Ghosts',
#  'Anyone but You',
#  'Fallen Leaves',
#  'Radical',
#  'Fingernails',
#  'My Love Affair With Marriage',
#  'Foe',
#  'The Creator',
#  'My Sailor, My Love',
#  'Cassandro',
#  'Love at First Sight',
#  'We Kill for Love',
#  'Choose Love',
#  'Before, Now & Then',
#  'Love Life',
#  'Red, White & Royal Blue',
#  'Love in Taipei',
#  'The Eternal Memory',
#  'Passages',
#  'Sublime',
#  'Shooting Stars',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
# ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter %50 == 0:
        time.sleep(1)
        
    # Add 1 to the request counter
    request_counter +=1
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(url + title + tmdb_key_string).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:

        # Get movie id
        movie_id = response['results'][0]['id']

        # Make a request for a the full movie details
        full_movie_details = "https://api.themoviedb.org/3/movie/"
        full_url = full_movie_details + movie_id + tmdb_key_string

        # Execute "GET" request with url
        response_movie_details = requests.get(full_url).json()
        
        # Extract the genre names into a list
        genres = []
        for genre in response_movie_details['genres']:
            genres.append(genre['name'])

        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for spoken in response_movie_details['spoken_languages']:
            spoken_languages.append(spoken['english_name'])

        # Extract the production_countries' name into a list
        production_countries = []
        for country in response_movie_details['production_countries']:
            production_countries.append(country['name'])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append({
            "title": response_movie_details['title'],
            "original_title": response_movie_details['original_title'],
            "budget": response_movie_details['budget'],
            "original_language": response_movie_details['original_language'],
            "homepage": response_movie_details['homepage'],
            "overview": response_movie_details['overview'],
            "popularity": response_movie_details['popularity'],
            "runtime": response_movie_details['runtime'],
            "revenue": response_movie_details['revenue'], 
            "release_date": response_movie_details['release_date'],
            "vote_average": response_movie_details['vote_average'],
            "vote_count": response_movie_details['vote_count'],
            "genres": response_movie_details['genres'], 
            "spoken_languages": response_movie_details['spoken_languages'],
            "production_countries": response_movie_details['production_countries'],
        })

        # Print out the title that was found
        print("Found " + title) 
    except:
        print("Found " + title)
# Out:
# Found It Ends With Us
# Found From Scorsese With Love: A Tribute to Powell-Pressburger Movie
# Found Fly Me to the Moon
# Found Handling the Undead
# Found Challengers
# Found Unsung Hero
# Found Love Lies Bleeding
# Found Bleeding Love
# Found Bob Marley: One Love
# Found Molli and Max in the Future
# Found The Taste of Things
# Found Pictures of Ghosts
# Found Anyone but You
# Found Fallen Leaves
# Found Radical
# Found Fingernails
# Found My Love Affair With Marriage
# Found Foe
# Found The Creator
# Found My Sailor, My Love
# Found Cassandro
# Found Love at First Sight
# Found We Kill for Love
# Found Choose Love
# Found Before, Now & Then
# Found Love Life
# Found Red, White & Royal Blue
# Found Love in Taipei
# Found The Eternal Memory
# Found Passages
# Found Sublime
# Found Shooting Stars
# Found The Attachment Diaries
# Found What’s Love Got to Do With It?’ Probably a Lo
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5],indent=4))
# Out:
# []

# %%
# Convert the results to a DataFrame
tmdb_movies_list_df = pd.json_normalize(tmdb_movies_list)
tmdb_movies_list_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merge_df = pd.merge(reviews_list_df, tmdb_movies_list_df, on="title")
merge_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/ch/bqy21ns16wqg8gz7rd0s_46m0000gn/T/ipykernel_84326/513266711.py in ?()
#       1 # Merge the New York Times reviews and TMDB DataFrames on title
# ----> 2 merge_df = pd.merge(reviews_list_df, tmdb_movies_list_df, on="title")
#       3 merge_df
#
# /opt/anaconda3/envs/py310/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
